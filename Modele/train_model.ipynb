# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import joblib
import streamlit as st

# %%
df=pd.read_csv('patients_advanced.csv')

# %%
df.head()
# Out:
#   patient_id  age  gender  heart_rate  respiratory_rate  oxygen_saturation  \
# 0       P001   67  Female          80                18                 96
# 1       P002   27    Male          81                22                 93
# 2       P003   51    Male         104                15                 94
# 3       P004   69    Male          62                16                 97
# 4       P005   48  Female          81                23                 91
#
#   blood_pressure pain_level          condition  needs_surgery  \
# 0         108/82   Moderate             Hernia           True
# 1         139/75     Severe             Hernia           True
# 2         137/97     Severe         Gallstones           True
# 3          96/80   Moderate           Fracture           True
# 4         117/84     Severe  Bowel Obstruction           True
#
#    surgery_duration
# 0                73
# 1                77
# 2                54
# 3                47
# 4                76

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   0
# gender                0
# heart_rate            0
# respiratory_rate      0
# oxygen_saturation     0
# blood_pressure        0
# pain_level           31
# condition             0
# needs_surgery         0
# surgery_duration      0
# dtype: int64

# %%
df['condition'].value_counts(normalize=True)
# Out:
# condition
# Fracture             0.167
# Gallstones           0.151
# Hernia               0.118
# Kidney Stones        0.117
# Appendicitis         0.091
# Torn ACL             0.091
# Dislocated Knee      0.091
# Bowel Obstruction    0.064
# Stroke               0.062
# Heart Attack         0.048
# Name: proportion, dtype: float64
